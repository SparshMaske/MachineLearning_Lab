# %% [markdown]
# <a href="https://colab.research.google.com/github/SparshMaske/MachineLearning_Lab/blob/main/ML_lab1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
import sklearn as skl
from sklearn import linear_model
from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_squared_error, r2_score
import matplotlib.pyplot as plt

# %%
df=pd.read_csv('/content/ML.csv')

# %%
df.head()
# Out:
#    area housing  price
# 0            10    100
# 1            25    250
# 2            45    450
# 3            55    550
# 4            70    700

# %%
print("Number of rows:", df.shape[0])
print("Number of columns:", df.shape[1])
# Out:
# Number of rows: 40
# Number of columns: 2

# %%
X = df[['area housing']]
y = df['price']

# %%
plt.figure(figsize=(8, 6))
plt.scatter(df['Area_Housing(Sq)'], df['Prices'])
plt.xlabel('Area_Housing(Sq)')
plt.ylabel('Prices')
plt.title('Scatter Plot of Housing Area vs. Prices')
plt.grid(True)
plt.show()

# %%
model = LinearRegression()
model.fit(X, y)
# Out:
# LinearRegression()

# %%
y_pred = model.predict(X)

# %%
plt.scatter(X, y, color='blue', label='Actual Data')
plt.plot(X, y_pred, color='red', label='Regression Line')
plt.xlabel('area housing')
plt.ylabel('price')
plt.title('Linear Regression: Area vs Price in Lakhs')
plt.legend()
plt.show()

# %%
r2 = r2_score(y, y_pred)
print("R2 score:", r2)
# Out:
# R2 score: 1.0
